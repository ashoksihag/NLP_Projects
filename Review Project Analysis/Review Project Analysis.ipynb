# %% [markdown]
# # Problem Statement:
#
# A popular mobile phone brand, Lenovo has launched their budget smartphone in the Indian market. The client wants to understand the VOC (voice of the customer) on the product. This will be useful to not just evaluate the current product, but to also get some direction for developing the product pipeline. The client is particularly interested in the different aspects that customers care about. Product reviews by customers on a leading e-commerce site should provide a good view.
#
# ### Domain:
# Amazon reviews for a leading phone brand
#
# ### Analysis to be done:
# POS tagging, topic modeling using LDA, and topic interpretation

# %% [markdown]
# ### Steps to perform:
#
# Discover the topics in the reviews and present it to business in a consumable format. Employ techniques in syntactic processing and topic modeling.
#
# Perform specific cleanup, POS tagging, and restricting to relevant POS tags, then, perform topic modeling using LDA. Finally, give business-friendly names to the topics and make a table for business.

# %% [markdown]
# #### Task 1: Read the .csv file using Pandas. Take a look at the top few records.

# %%
import pandas as pd

# %%
reviews = pd.read_csv('K8 Reviews v0.2.csv')

# %%
reviews.head()
# Out:
#    sentiment                                             review
# 0          1             Good but need updates and improvements
# 1          0  Worst mobile i have bought ever, Battery is dr...
# 2          1  when I will get my 10% cash back.... its alrea...
# 3          1                                               Good
# 4          0  The worst phone everThey have changed the last...

# %%
reviews.shape
# Out:
# (14675, 2)

# %% [markdown]
# #### Task 2: Normalize casings for the review text and extract the text into a list for easier manipulation.

# %%
reviews = reviews.review.values

# %%
reviews = [text.lower() for text in reviews]
reviews[:3]
# Out:
# ['good but need updates and improvements',
#  "worst mobile i have bought ever, battery is draining like hell, backup is only 6 to 7 hours with internet uses, even if i put mobile idle its getting discharged.this is biggest lie from amazon & lenove which is not at all expected, they are making full by saying that battery is 4000mah & booster charger is fake, it takes at least 4 to 5 hours to be fully charged.don't know how lenovo will survive by making full of us.please don;t go for this else you will regret like me.",
#  'when i will get my 10% cash back.... its already 15 january..']

# %% [markdown]
# #### Task 3: Tokenize the reviews using NLTKs word_tokenize function.

# %%
from nltk.tokenize import word_tokenize
reviews = [word_tokenize(text) for text in reviews]

# %%
reviews[:1]
# Out:
# [['good', 'but', 'need', 'updates', 'and', 'improvements']]

# %% [markdown]
# #### Task 4: Perform parts-of-speech tagging on each sentence using the NLTK POS tagger.

# %%
import nltk
from nltk.tag import pos_tag

# %%
reviews = [nltk.pos_tag(review) for review in reviews]

# %%
reviews[:1]
# Out:
# [[('good', 'JJ'),
#   ('but', 'CC'),
#   ('need', 'VBP'),
#   ('updates', 'NNS'),
#   ('and', 'CC'),
#   ('improvements', 'NNS')]]

# %% [markdown]
# #### Task 5: For the topic model, we should  want to include only nouns.
#
# 1. Find out all the POS tags that correspond to nouns.
#
# 2. Limit the data to only terms with these tags.

# %%
def noun_pos_tags(reviews):
    reviews_postag=[]
    for review in reviews:
        for word,pos in review:
            if pos=='NN' or pos=='NNS' or pos=='NNP' or pos=='NNPS':
                reviews_postag.append(word)
            else:
                pass
    return reviews_postag

# %%
tagged_reviews = noun_pos_tags(reviews)
tagged_reviews
# Out:
# ['updates',
#  'improvements',
#  'mobile',
#  'i',
#  'battery',
#  'hell',
#  'backup',
#  'hours',
#  'uses',
#  'idle',
#  'discharged.this',
#  'lie',
#  'amazon',
#  'lenove',
#  'battery',
#  'charger',
#  'hours',
#  'don',
#  'i',
#  '%',
#  'cash',
#  '..',
#  'phone',
#  'everthey',
#  'phone',
#  'problem',
#  'amazon',
#  'phone',
#  'amazon',
#  'camerawaste',
#  'money',
#  'phone',
#  'allot',
#  '..',
#  'reason',
#  'k8',
#  'battery',
#  'level',
#  'problems',
#  'phone',
#  'hanging',
#  'problems',
#  'note',
#  'station',
#  'ahmedabad',
#  'years',
#  'phone',
#  'lenovo',
#  'lot',
#  'glitches',
#  'thing',
#  'options',
#  'wrost',
#  'phone',
#  'charger',
#  'damage',
#  'months',
#  'item',
#  'battery',
#  'life',
#  'i',
#  'battery',
#  'problem',
#  'motherboard',
#  'problem',
#  'months',
#  'mobile',
#  'life',
#  'phone',
#  'slim',
#  'battry',
#  'backup',
#  'screen',
#  'headset',
#  'time',
#  'i',
#  'product',
#  'prize',
#  'range',
#  'specification',
#  'comparison',
#  'mobile',
#  'range',
#  'i',
#  'phone',
#  'seal',
#  'i',
#  'credit',
#  'card',
#  'i',
#  '..',
#  '..',
#  'deal',
#  'amazon',
#  '..',
#  'battery',
#  '..',
#  'solutions',
#  'battery',
#  'life',
#  'smartphone',
#  'galery',
#  'problem',
#  'speaker',
#  'phone',
#  'camera',
#  'speed.excellent',
#  'features.excelent',
#  'battery',
#  'product',
#  'product',
#  'camera',
#  'os',
#  'battery',
#  'phone',
#  'product',
#  '..',
#  'options',
#  'cast',
#  'screen',
#  'wifi',
#  'call',
#  'option',
#  'mobile',
#  'hotspot',
#  'phone',
#  'usb',
#  'cable',
#  'phone',
#  'price',
#  'mobile',
#  'lenovo',
#  'display',
#  'specifications',
#  'functions',
#  'phone',
#  'any1',
#  '..',
#  'i',
#  'fon',
#  'fon',
#  'speekars',
#  'i',
#  'phone',
#  'issue',
#  'colors',
#  'screen',
#  'update',
#  'oreo',
#  'battery',
#  'back-up',
#  'heating',
#  'problem',
#  'update',
#  'phone',
#  'battery',
#  'update',
#  'oreo',
#  '😒😒☹️',
#  'one',
#  'sim',
#  'customer',
#  'service',
#  'performance',
#  'battery',
#  'camera',
#  'backup',
#  'pricefull',
#  'passa',
#  'wasole',
#  'phone',
#  'phone',
#  'performance',
#  '..',
#  'signal',
#  'restarts',
#  'phone',
#  'bcoms',
#  '..',
#  'plzz',
#  'dont',
#  'round',
#  'performance',
#  'rs.3000',
#  'span',
#  'days',
#  'trust',
#  'deals',
#  'amazon',
#  'disappointment',
#  'signal',
#  'problems',
#  'headache',
#  'problems',
#  'calls',
#  'range',
#  'phone',
#  'rate',
#  'camera',
#  'quality',
#  'product',
#  'mobile',
#  'price',
#  'features',
#  'mobile',
#  'price',
#  'quality',
#  'camera',
#  'mins',
#  'quality',
#  'phone',
#  'i',
#  'issue',
#  'i',
#  'k8',
#  'sell',
#  'phone',
#  'take',
#  'hr',
#  'charge',
#  '.....',
#  'ekdam',
#  'network',
#  'problem',
#  'k8',
#  'camera',
#  'quality',
#  'performance',
#  'phone',
#  'performance',
#  'rm',
#  'memory',
#  'superb',
#  'featurs',
#  'battery',
#  'phone😍😍',
#  'value',
#  'money',
#  'lenovo',
#  'k8',
#  'problem',
#  'speaker',
#  'breakups',
#  'problem',
#  'hour',
#  'phone',
#  'heating',
#  'problem',
#  'choice',
#  'battery',
#  'standby',
#  'problem',
#  'battery',
#  'camera',
#  'jet',
#  'speed',
#  'apps.👌👌',
#  'product',
#  'ok',
#  'screen',
#  'cast',
#  'tv',
#  'miracast',
#  'charging',
#  'hours',
#  'contacts',
#  'files',
#  'google',
#  'card',
#  'total',
#  'device',
#  'usage',
#  'battery',
#  'day',
#  'con',
#  'phone',
#  'battery',
#  'mah',
#  'battery',
#  'camera',
#  'quality',
#  'depth',
#  'mode',
#  'focus',
#  'thing',
#  'i',
#  'device',
#  'display',
#  'india',
#  'ka',
#  'battery',
#  'offer',
#  'hour',
#  '%',
#  'network',
#  'signals',
#  'calls',
#  'coverage',
#  'area.lenovo',
#  'people',
#  'mobile',
#  'mobile',
#  'range',
#  'battery',
#  'backup',
#  'mark',
#  'weight',
#  '....',
#  'price',
#  'point',
#  'camera',
#  'mo',
#  'issue',
#  'system',
#  'system',
#  'updates',
#  'superb',
#  'mobile',
#  'phone',
#  'product',
#  'delivery',
#  'rs.10000',
#  'gestures',
#  'features',
#  'issues',
#  'brands',
#  'mobile.great',
#  'specifications',
#  '.camera',
#  'focus',
#  'thanks',
#  'amazon',
#  'lenovo',
#  'buy',
#  'guys',
#  'verigood',
#  'verigood.best',
#  'product',
#  'time',
#  'naugat',
#  'product',
#  'cost',
#  'phone',
#  'feels',
#  'nerve',
#  'radiation',
#  'need',
#  'fix',
#  'matter',
#  'safety',
#  'security',
#  'customer.fifthly',
#  'issues',
#  'hardware',
#  'issues',
#  'service',
#  'centers',
#  'location',
#  'availability',
#  'time',
#  'customers',
#  'product',
#  'features',
#  'issues',
#  'recording',
#  'option',
#  'product',
#  'expectations.camera',
#  'quality',
#  'snap',
#  'product',
#  'device',
#  'product',
#  'amazon',
#  'phone',
#  'hello',
#  '..',
#  'performance',
#  'device',
#  'picture',
#  'i',
#  'use',
#  'hours',
#  'data',
#  'battery',
#  'mode',
#  'performanc',
#  'turbo',
#  'charger',
#  'waste',
#  'charger',
#  'return',
#  'request.pros',
#  'rest',
#  'good.cameradesignperformance',
#  'etc',
#  'phone',
#  'problem',
#  'product',
#  '☺️🙂',
#  'product',
#  '..',
#  'lots',
#  'malfunction',
#  'donot',
#  'product',
#  'look',
#  'sleekness',
#  'phone',
#  'features',
#  'phone',
#  'phone',
#  'features',
#  'sound',
#  'controler',
#  'option',
#  'shortcut',
#  'shutter',
#  'voice',
#  'call',
#  'recorder',
#  'camera',
#  'quality',
#  'performance',
#  'class',
#  'phone',
#  'time',
#  'lenovo',
#  'i',
#  'note',
#  'note',
#  'kind',
#  'thinking',
#  'load',
#  'battery',
#  'class',
#  'defuces',
#  'time',
#  'charge',
#  'time',
#  'charger.gallery',
#  'othet',
#  'apps',
#  'stock',
#  'android',
#  'thing',
#  'process.android.com',
#  '..',
#  'ok',
#  'product',
#  'problem',
#  'i',
#  'lenovo',
#  'k8',
#  'note',
#  'handset',
#  'times',
#  'charger',
#  'service',
#  'centre',
#  'month',
#  'fix',
#  'u',
#  'features',
#  'gift',
#  'raping',
#  'poorwords',
#  'money',
#  'work',
#  'i',
#  'product',
#  'anyone',
#  'tv',
#  'cast',
#  'screen',
#  'option',
#  'option',
#  'device',
#  'chromecast',
#  'casting',
#  'model',
#  'phone',
#  'range',
#  'phone',
#  'u',
#  'features',
#  'problems',
#  'arises',
#  'money',
#  'sim',
#  'slot',
#  'i',
#  'delivery',
#  'star',
#  'bcz',
#  'i',
#  'lenovo',
#  'fan',
#  'i',
#  'mobile',
#  'year',
#  'time',
#  'guess',
#  'phone',
#  'lots',
#  'features',
#  'look',
#  'gaming',
#  'music',
#  '..',
#  'i',
#  'deca',
#  'core',
#  'processor',
#  'quad',
#  'core',
#  'phone',
#  'speakers',
#  'speaker',
#  'holes',
#  'buyers',
#  'camera',
#  'display',
#  'battery',
#  'keeps',
#  '%',
#  'phone',
#  'use',
#  'battery',
#  'backup',
#  'problem',
#  'phone',
#  '....',
#  'product',
#  'cash',
#  'way',
#  'fool',
#  'cash',
#  'back.lol',
#  'mobile',
#  'mobile',
#  '.but',
#  'heating',
#  'problem',
#  'thing',
#  'popularity',
#  'segment',
#  'productcamera',
#  'greatsound',
#  'superb',
#  'mobile',
#  'process',
#  'drawback',
#  'turbo',
#  'charger',
#  'mobile',
#  'experience',
#  'lenovo',
#  'note',
#  'problems',
#  'm',
#  'battery',
#  'problem',
#  'camera',
#  'problems',
#  'plz',
#  'buy',
#  'phones',
#  'phone',
#  '..',
#  'mo',
#  'expectation',
#  '😪',
#  'camera',
#  'mark',
#  '.....',
#  'issues',
#  'needs',
#  '....',
#  'i',
#  'lenovo',
#  'sales',
#  'dolby',
#  'feature',
#  'lenovo',
#  'switch',
#  'i',
#  'k6',
#  'i',
#  'sofwares',
#  'phone',
#  'please',
#  'battery',
#  'camera',
#  'shadow',
#  'functions',
#  'phone',
#  'performance',
#  'waste',
#  'money',
#  'phone',
#  'add',
#  'please',
#  'mi',
#  'brand',
#  'mobile',
#  'range',
#  'product',
#  'phone',
#  'i',
#  'lenovo',
#  'stock',
#  'android',
#  'story',
#  'battery',
#  'drain',
#  'time',
#  'camera',
#  'joke',
#  'update',
#  'lenovo',
#  'mobile',
#  'problem',
#  'quality',
#  'phn',
#  'battery',
#  'time',
#  'display',
#  'disadvantage',
#  'model',
#  'battery',
#  '..',
#  'features',
#  'battery',
#  'backup',
#  'i',
#  'lenovo',
#  'k8',
#  'note',
#  'model',
#  'type',
#  'm2cb2',
#  'days',
#  'product',
#  'i',
#  'problem',
#  'amazon',
#  'product',
#  'description',
#  'handset',
#  'slots',
#  'slot',
#  'support',
#  'whereas',
#  'supports',
#  'phone.no',
#  'effects',
#  'cameras',
#  'support',
#  'sim',
#  'slot',
#  'disadvantage',
#  'features',
#  'backlogs1',
#  'ram',
#  'delay',
#  'responding.2',
#  'battery',
#  'mah.3',
#  'delay',
#  'camera',
#  'operating',
#  'response.4',
#  'delay',
#  'contact',
#  'searching',
#  'contact',
#  'time',
#  'contact.5',
#  'mobile',
#  'range.friends',
#  '..',
#  'i',
#  'u',
#  'camera',
#  'camera',
#  'need',
#  'product',
#  'price',
#  'range',
#  'speaker',
#  'channel',
#  'speaker',
#  'camera',
#  'wakeup',
#  'earphone',
#  'quality',
#  'jbl',
#  'camera',
#  'product',
#  'product',
#  'phone',
#  'hang',
#  'hota',
#  'hai',
#  'phone',
#  'phone',
#  'connectivity',
#  'charging',
#  'talk',
#  'time',
#  'battery',
#  'twin',
#  'camera',
#  'hands',
#  'mine',
#  'update',
#  'connection',
#  'phone',
#  'information',
#  'gorilla',
#  'glass',
#  'screen',
#  'glass',
#  'phone',
#  'grasp',
#  'sofa',
#  'lenovo',
#  'screen',
#  'rating',
#  'stars',
#  'delivery',
#  'delivery',
#  'districts',
#  'phone',
#  'bit',
#  'notification',
#  'sounds',
#  'bit',
#  'photos',
#  'lot',
#  'memory',
#  'clarity',
#  'memory',
#  'features',
#  'i',
#  'return',
#  'note',
#  'august.this',
#  'mobile',
#  'performance',
#  'battery',
#  'battery',
#  'mobile.so',
#  'plz',
#  'batterybattery',
#  'drain',
#  'hrsit',
#  'mah',
#  'performance',
#  '😎😎',
#  'configuration',
#  'auto',
#  'auto',
#  'touch',
#  'problem',
#  'jan',
#  'average',
#  'phone',
#  'price',
#  'cameras',
#  'performance',
#  'day',
#  'ok',
#  'lenovo',
#  'name',
#  'expectations',
#  'phone',
#  'course',
#  'use',
#  'k8',
#  'performance',
#  'product',
#  'specifications',
#  'thanks',
#  'product',
#  'time',
#  'phone',
#  'terms',
#  'specifications',
#  'sound',
#  'battery',
#  'screen',
#  'camera',
#  'ram',
#  'rom',
#  'alongwith',
#  'gorilla',
#  'glass',
#  'things',
#  'mobile',
#  'pocket',
#  'lacks',
#  'pc',
#  'connection',
#  'etc',
#  'phone',
#  'update',
#  'phone',
#  '..',
#  'month',
#  'gb',
#  'memory',
#  'phone',
#  'camera',
#  'performance',
#  'mid',
#  'range',
#  'phones',
#  'ye',
#  'amazon',
#  'hai',
#  '..',
#  'phn',
#  'kharida',
#  'lenovo',
#  'k8',
#  'note',
#  'game',
#  'ka',
#  'issue',
#  'hai',
#  '..',
#  'b.c',
#  'ly',
#  'bolte',
#  'hai',
#  'par',
#  'behanchod',
#  'hai',
#  'bhosdi',
#  'jane',
#  'ke',
#  'service',
#  'bhi',
#  'inka',
#  'bhosdi',
#  'game',
#  'khelke',
#  'kenya',
#  'hai',
#  'koi',
#  'problem',
#  'nai',
#  'hai',
#  '..',
#  'behanchod',
#  'phone',
#  'bhej',
#  'diya',
#  'mat',
#  'kaharidna',
#  '..',
#  'amazon',
#  'se',
#  '..',
#  'bhot',
#  'bhosdi',
#  'hai',
#  'volte',
#  'sms',
#  'phone',
#  'mode',
#  '..',
#  'things',
#  'running',
#  'problem',
#  'till',
#  'phone',
#  'camera',
#  'phone',
#  'heating',
#  'problem',
#  'depth',
#  'effect',
#  'phone',
#  'depth',
#  'effect',
#  'mi',
#  'a1',
#  'youif',
#  'holic',
#  'phone',
#  'selfie',
#  'compare',
#  'phones',
#  'price',
#  'range',
#  'phone',
#  'top',
#  'terms',
#  'selfiein',
#  'terms',
#  'processor',
#  'i',
#  'snapdragon',
#  'bcz',
#  'phone',
#  'battery',
#  'phones',
#  'processor',
#  'technology',
#  'snapdragon',
#  'nm',
#  'efficient',
#  'lenovo',
#  'day',
#  'battery',
#  'hr',
#  'phone',
#  '%',
#  '%',
#  'hr',
#  'hrs.on',
#  'usage',
#  'i',
#  'mind',
#  'cons',
#  'phone',
#  'phone',
#  '.......',
#  'problem',
#  'phone',
#  'condition.camera',
#  'quality',
#  'processor',
#  'turbo',
#  'features',
#  'parfomce',
#  'product',
#  '👌👌👌',
#  'mobiles',
#  'days',
#  'record',
#  'facilities.no',
#  'instructions',
#  'note',
#  'product',
#  'hello',
#  'guys',
#  'i',
#  'kaji',
#  'phone',
#  'lenovo',
#  'k8',
#  'note',
#  'i',
#  'feature',
#  'decide',
#  'bu',
#  'days',
#  'lenovo',
#  'game',
#  'temple',
#  'type',
#  'problem',
#  'opinion',
#  'guys',
#  'product',
#  'money',
#  'product',
#  'phone',
#  'battery',
#  'life',
#  'phone',
#  'issue',
#  'phone',
#  'call',
#  'recorder',
#  'backup',
#  'key',
#  'problem',
#  'mobile',
#  '.....',
#  'performance',
#  '....',
#  'thanx',
#  '....',
#  'phone',
#  'wrost',
#  'mobile',
#  'charge',
#  'lot',
#  'tym',
#  'turbo',
#  'chrger',
#  'selfie',
#  'camera',
#  'mobile',
#  'handset',
#  ...]

# %% [markdown]
# #### Task 7: Remove stopwords and punctuation (if there are any).

# %%
#removing punctuation

tagged_reviews = [word for word in tagged_reviews if word.isalpha()]

# %%
len(tagged_reviews)
# Out:
# 85077

# %%
# removing stopwords

from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
tagged_reviews = [w for w in tagged_reviews if not w in stop_words]

# %%
len(tagged_reviews)
# Out:
# 81822

# %%
tagged_reviews
# Out:
# ['updates',
#  'improvements',
#  'mobile',
#  'battery',
#  'hell',
#  'backup',
#  'hours',
#  'uses',
#  'idle',
#  'lie',
#  'amazon',
#  'lenove',
#  'battery',
#  'charger',
#  'hours',
#  'cash',
#  'phone',
#  'everthey',
#  'phone',
#  'problem',
#  'amazon',
#  'phone',
#  'amazon',
#  'camerawaste',
#  'money',
#  'phone',
#  'allot',
#  'reason',
#  'battery',
#  'level',
#  'problems',
#  'phone',
#  'hanging',
#  'problems',
#  'note',
#  'station',
#  'ahmedabad',
#  'years',
#  'phone',
#  'lenovo',
#  'lot',
#  'glitches',
#  'thing',
#  'options',
#  'wrost',
#  'phone',
#  'charger',
#  'damage',
#  'months',
#  'item',
#  'battery',
#  'life',
#  'battery',
#  'problem',
#  'motherboard',
#  'problem',
#  'months',
#  'mobile',
#  'life',
#  'phone',
#  'slim',
#  'battry',
#  'backup',
#  'screen',
#  'headset',
#  'time',
#  'product',
#  'prize',
#  'range',
#  'specification',
#  'comparison',
#  'mobile',
#  'range',
#  'phone',
#  'seal',
#  'credit',
#  'card',
#  'deal',
#  'amazon',
#  'battery',
#  'solutions',
#  'battery',
#  'life',
#  'smartphone',
#  'galery',
#  'problem',
#  'speaker',
#  'phone',
#  'camera',
#  'battery',
#  'product',
#  'product',
#  'camera',
#  'os',
#  'battery',
#  'phone',
#  'product',
#  'options',
#  'cast',
#  'screen',
#  'wifi',
#  'call',
#  'option',
#  'mobile',
#  'hotspot',
#  'phone',
#  'usb',
#  'cable',
#  'phone',
#  'price',
#  'mobile',
#  'lenovo',
#  'display',
#  'specifications',
#  'functions',
#  'phone',
#  'fon',
#  'fon',
#  'speekars',
#  'phone',
#  'issue',
#  'colors',
#  'screen',
#  'update',
#  'oreo',
#  'battery',
#  'heating',
#  'problem',
#  'update',
#  'phone',
#  'battery',
#  'update',
#  'oreo',
#  'one',
#  'sim',
#  'customer',
#  'service',
#  'performance',
#  'battery',
#  'camera',
#  'backup',
#  'pricefull',
#  'passa',
#  'wasole',
#  'phone',
#  'phone',
#  'performance',
#  'signal',
#  'restarts',
#  'phone',
#  'bcoms',
#  'plzz',
#  'dont',
#  'round',
#  'performance',
#  'span',
#  'days',
#  'trust',
#  'deals',
#  'amazon',
#  'disappointment',
#  'signal',
#  'problems',
#  'headache',
#  'problems',
#  'calls',
#  'range',
#  'phone',
#  'rate',
#  'camera',
#  'quality',
#  'product',
#  'mobile',
#  'price',
#  'features',
#  'mobile',
#  'price',
#  'quality',
#  'camera',
#  'mins',
#  'quality',
#  'phone',
#  'issue',
#  'sell',
#  'phone',
#  'take',
#  'hr',
#  'charge',
#  'ekdam',
#  'network',
#  'problem',
#  'camera',
#  'quality',
#  'performance',
#  'phone',
#  'performance',
#  'rm',
#  'memory',
#  'superb',
#  'featurs',
#  'battery',
#  'value',
#  'money',
#  'lenovo',
#  'problem',
#  'speaker',
#  'breakups',
#  'problem',
#  'hour',
#  'phone',
#  'heating',
#  'problem',
#  'choice',
#  'battery',
#  'standby',
#  'problem',
#  'battery',
#  'camera',
#  'jet',
#  'speed',
#  'product',
#  'ok',
#  'screen',
#  'cast',
#  'tv',
#  'miracast',
#  'charging',
#  'hours',
#  'contacts',
#  'files',
#  'google',
#  'card',
#  'total',
#  'device',
#  'usage',
#  'battery',
#  'day',
#  'con',
#  'phone',
#  'battery',
#  'mah',
#  'battery',
#  'camera',
#  'quality',
#  'depth',
#  'mode',
#  'focus',
#  'thing',
#  'device',
#  'display',
#  'india',
#  'ka',
#  'battery',
#  'offer',
#  'hour',
#  'network',
#  'signals',
#  'calls',
#  'coverage',
#  'people',
#  'mobile',
#  'mobile',
#  'range',
#  'battery',
#  'backup',
#  'mark',
#  'weight',
#  'price',
#  'point',
#  'camera',
#  'mo',
#  'issue',
#  'system',
#  'system',
#  'updates',
#  'superb',
#  'mobile',
#  'phone',
#  'product',
#  'delivery',
#  'gestures',
#  'features',
#  'issues',
#  'brands',
#  'specifications',
#  'focus',
#  'thanks',
#  'amazon',
#  'lenovo',
#  'buy',
#  'guys',
#  'verigood',
#  'product',
#  'time',
#  'naugat',
#  'product',
#  'cost',
#  'phone',
#  'feels',
#  'nerve',
#  'radiation',
#  'need',
#  'fix',
#  'matter',
#  'safety',
#  'security',
#  'issues',
#  'hardware',
#  'issues',
#  'service',
#  'centers',
#  'location',
#  'availability',
#  'time',
#  'customers',
#  'product',
#  'features',
#  'issues',
#  'recording',
#  'option',
#  'product',
#  'quality',
#  'snap',
#  'product',
#  'device',
#  'product',
#  'amazon',
#  'phone',
#  'hello',
#  'performance',
#  'device',
#  'picture',
#  'use',
#  'hours',
#  'data',
#  'battery',
#  'mode',
#  'performanc',
#  'turbo',
#  'charger',
#  'waste',
#  'charger',
#  'return',
#  'rest',
#  'etc',
#  'phone',
#  'problem',
#  'product',
#  'product',
#  'lots',
#  'malfunction',
#  'donot',
#  'product',
#  'look',
#  'sleekness',
#  'phone',
#  'features',
#  'phone',
#  'phone',
#  'features',
#  'sound',
#  'controler',
#  'option',
#  'shortcut',
#  'shutter',
#  'voice',
#  'call',
#  'recorder',
#  'camera',
#  'quality',
#  'performance',
#  'class',
#  'phone',
#  'time',
#  'lenovo',
#  'note',
#  'note',
#  'kind',
#  'thinking',
#  'load',
#  'battery',
#  'class',
#  'defuces',
#  'time',
#  'charge',
#  'time',
#  'othet',
#  'apps',
#  'stock',
#  'android',
#  'thing',
#  'ok',
#  'product',
#  'problem',
#  'lenovo',
#  'note',
#  'handset',
#  'times',
#  'charger',
#  'service',
#  'centre',
#  'month',
#  'fix',
#  'u',
#  'features',
#  'gift',
#  'raping',
#  'poorwords',
#  'money',
#  'work',
#  'product',
#  'anyone',
#  'tv',
#  'cast',
#  'screen',
#  'option',
#  'option',
#  'device',
#  'chromecast',
#  'casting',
#  'model',
#  'phone',
#  'range',
#  'phone',
#  'u',
#  'features',
#  'problems',
#  'arises',
#  'money',
#  'sim',
#  'slot',
#  'delivery',
#  'star',
#  'bcz',
#  'lenovo',
#  'fan',
#  'mobile',
#  'year',
#  'time',
#  'guess',
#  'phone',
#  'lots',
#  'features',
#  'look',
#  'gaming',
#  'music',
#  'deca',
#  'core',
#  'processor',
#  'quad',
#  'core',
#  'phone',
#  'speakers',
#  'speaker',
#  'holes',
#  'buyers',
#  'camera',
#  'display',
#  'battery',
#  'keeps',
#  'phone',
#  'use',
#  'battery',
#  'backup',
#  'problem',
#  'phone',
#  'product',
#  'cash',
#  'way',
#  'fool',
#  'cash',
#  'mobile',
#  'mobile',
#  'heating',
#  'problem',
#  'thing',
#  'popularity',
#  'segment',
#  'productcamera',
#  'greatsound',
#  'superb',
#  'mobile',
#  'process',
#  'drawback',
#  'turbo',
#  'charger',
#  'mobile',
#  'experience',
#  'lenovo',
#  'note',
#  'problems',
#  'battery',
#  'problem',
#  'camera',
#  'problems',
#  'plz',
#  'buy',
#  'phones',
#  'phone',
#  'mo',
#  'expectation',
#  'camera',
#  'mark',
#  'issues',
#  'needs',
#  'lenovo',
#  'sales',
#  'dolby',
#  'feature',
#  'lenovo',
#  'switch',
#  'sofwares',
#  'phone',
#  'please',
#  'battery',
#  'camera',
#  'shadow',
#  'functions',
#  'phone',
#  'performance',
#  'waste',
#  'money',
#  'phone',
#  'add',
#  'please',
#  'mi',
#  'brand',
#  'mobile',
#  'range',
#  'product',
#  'phone',
#  'lenovo',
#  'stock',
#  'android',
#  'story',
#  'battery',
#  'drain',
#  'time',
#  'camera',
#  'joke',
#  'update',
#  'lenovo',
#  'mobile',
#  'problem',
#  'quality',
#  'phn',
#  'battery',
#  'time',
#  'display',
#  'disadvantage',
#  'model',
#  'battery',
#  'features',
#  'battery',
#  'backup',
#  'lenovo',
#  'note',
#  'model',
#  'type',
#  'days',
#  'product',
#  'problem',
#  'amazon',
#  'product',
#  'description',
#  'handset',
#  'slots',
#  'slot',
#  'support',
#  'whereas',
#  'supports',
#  'effects',
#  'cameras',
#  'support',
#  'sim',
#  'slot',
#  'disadvantage',
#  'features',
#  'ram',
#  'delay',
#  'battery',
#  'delay',
#  'camera',
#  'operating',
#  'delay',
#  'contact',
#  'searching',
#  'contact',
#  'time',
#  'mobile',
#  'u',
#  'camera',
#  'camera',
#  'need',
#  'product',
#  'price',
#  'range',
#  'speaker',
#  'channel',
#  'speaker',
#  'camera',
#  'wakeup',
#  'earphone',
#  'quality',
#  'jbl',
#  'camera',
#  'product',
#  'product',
#  'phone',
#  'hang',
#  'hota',
#  'hai',
#  'phone',
#  'phone',
#  'connectivity',
#  'charging',
#  'talk',
#  'time',
#  'battery',
#  'twin',
#  'camera',
#  'hands',
#  'mine',
#  'update',
#  'connection',
#  'phone',
#  'information',
#  'gorilla',
#  'glass',
#  'screen',
#  'glass',
#  'phone',
#  'grasp',
#  'sofa',
#  'lenovo',
#  'screen',
#  'rating',
#  'stars',
#  'delivery',
#  'delivery',
#  'districts',
#  'phone',
#  'bit',
#  'notification',
#  'sounds',
#  'bit',
#  'photos',
#  'lot',
#  'memory',
#  'clarity',
#  'memory',
#  'features',
#  'return',
#  'note',
#  'mobile',
#  'performance',
#  'battery',
#  'battery',
#  'plz',
#  'batterybattery',
#  'drain',
#  'hrsit',
#  'mah',
#  'performance',
#  'configuration',
#  'auto',
#  'auto',
#  'touch',
#  'problem',
#  'jan',
#  'average',
#  'phone',
#  'price',
#  'cameras',
#  'performance',
#  'day',
#  'ok',
#  'lenovo',
#  'name',
#  'expectations',
#  'phone',
#  'course',
#  'use',
#  'performance',
#  'product',
#  'specifications',
#  'thanks',
#  'product',
#  'time',
#  'phone',
#  'terms',
#  'specifications',
#  'sound',
#  'battery',
#  'screen',
#  'camera',
#  'ram',
#  'rom',
#  'alongwith',
#  'gorilla',
#  'glass',
#  'things',
#  'mobile',
#  'pocket',
#  'lacks',
#  'pc',
#  'connection',
#  'etc',
#  'phone',
#  'update',
#  'phone',
#  'month',
#  'gb',
#  'memory',
#  'phone',
#  'camera',
#  'performance',
#  'mid',
#  'range',
#  'phones',
#  'ye',
#  'amazon',
#  'hai',
#  'phn',
#  'kharida',
#  'lenovo',
#  'note',
#  'game',
#  'ka',
#  'issue',
#  'hai',
#  'ly',
#  'bolte',
#  'hai',
#  'par',
#  'behanchod',
#  'hai',
#  'bhosdi',
#  'jane',
#  'ke',
#  'service',
#  'bhi',
#  'inka',
#  'bhosdi',
#  'game',
#  'khelke',
#  'kenya',
#  'hai',
#  'koi',
#  'problem',
#  'nai',
#  'hai',
#  'behanchod',
#  'phone',
#  'bhej',
#  'diya',
#  'mat',
#  'kaharidna',
#  'amazon',
#  'se',
#  'bhot',
#  'bhosdi',
#  'hai',
#  'volte',
#  'sms',
#  'phone',
#  'mode',
#  'things',
#  'running',
#  'problem',
#  'till',
#  'phone',
#  'camera',
#  'phone',
#  'heating',
#  'problem',
#  'depth',
#  'effect',
#  'phone',
#  'depth',
#  'effect',
#  'mi',
#  'youif',
#  'holic',
#  'phone',
#  'selfie',
#  'compare',
#  'phones',
#  'price',
#  'range',
#  'phone',
#  'top',
#  'terms',
#  'selfiein',
#  'terms',
#  'processor',
#  'snapdragon',
#  'bcz',
#  'phone',
#  'battery',
#  'phones',
#  'processor',
#  'technology',
#  'snapdragon',
#  'nm',
#  'efficient',
#  'lenovo',
#  'day',
#  'battery',
#  'hr',
#  'phone',
#  'hr',
#  'usage',
#  'mind',
#  'cons',
#  'phone',
#  'phone',
#  'problem',
#  'phone',
#  'quality',
#  'processor',
#  'turbo',
#  'features',
#  'parfomce',
#  'product',
#  'mobiles',
#  'days',
#  'record',
#  'instructions',
#  'note',
#  'product',
#  'hello',
#  'guys',
#  'kaji',
#  'phone',
#  'lenovo',
#  'note',
#  'feature',
#  'decide',
#  'bu',
#  'days',
#  'lenovo',
#  'game',
#  'temple',
#  'type',
#  'problem',
#  'opinion',
#  'guys',
#  'product',
#  'money',
#  'product',
#  'phone',
#  'battery',
#  'life',
#  'phone',
#  'issue',
#  'phone',
#  'call',
#  'recorder',
#  'backup',
#  'key',
#  'problem',
#  'mobile',
#  'performance',
#  'thanx',
#  'phone',
#  'wrost',
#  'mobile',
#  'charge',
#  'lot',
#  'tym',
#  'turbo',
#  'chrger',
#  'selfie',
#  'camera',
#  'mobile',
#  'handset',
#  'accessories',
#  'month',
#  'battery',
#  'something',
#  'issue',
#  'customers',
#  'super',
#  'description',
#  'software',
#  'update',
#  'product',
#  'ekdum',
#  'bakwas',
#  'performance',
#  'battery',
#  'camera',
#  'mistake',
#  'phone',
#  'battery',
#  'backup',
#  'phone',
#  'time',
#  'battery',
#  'side',
#  'buttons',
#  'problem',
#  'deapth',
#  'mode',
#  'finger',
#  'print',
#  'senser',
#  'camera',
#  'screen',
#  'gorilla',
#  'glass',
#  'phone',
#  'opinion',
#  'phone',
#  'works',
#  'battery',
#  'sim',
#  'data',
#  'camera',
#  'clarity',
#  'battery',
#  'backup',
#  'quality',
#  'product',
#  'age',
#  'group',
#  'thank',
#  'amazon',
#  'days',
#  'phone',
#  'price',
#  'battery',
#  'depth',
#  'camera',
#  'mode',
#  'thing',
#  'phone',
#  'days',
#  'use',
#  'phone',
#  'time',
#  'internet',
#  'lte',
#  'network',
#  'product',
#  'smartphone',
#  'bit',
#  'bugs',
#  'cost',
#  'product',
#  'phone',
#  'issues',
#  'response',
#  'customer',
#  'care',
#  'service',
#  'center',
#  'crap',
#  'traps',
#  'phone',
#  'variant',
#  'phone',
#  'battery',
#  'performance',
#  'charging',
#  'time',
#  'phone',
#  'work',
#  'touchscreen',
#  'features',
#  'rs',
#  'performance',
#  'money',
#  'service',
#  'amazon',
#  'purchase',
#  'months',
#  'handy',
#  'touch',
#  'product',
#  'thanks',
#  'product',
#  'amazon',
#  'lenovo',
#  'issue',
#  'phone',
#  'phone',
#  'issues',
#  'technician',
#  'amazon',
#  'amount',
#  'piece',
#  'headphone',
#  'jack',
#  'hotspot',
#  'battery',
#  'lot',
#  'usage',
#  'moto',
#  ...]

# %% [markdown]
# #### Task 6: Lemmatize.
#
# 1. Different forms of the terms need to be treated as one.
#
# 2. No need to provide POS tag to lemmatizer for now.

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
lemmatized_wordlist = [wordnet_lemmatizer.lemmatize(word) for word in tagged_reviews]

# %%
lemmatized_wordlist
# Out:
# ['update',
#  'improvement',
#  'mobile',
#  'battery',
#  'hell',
#  'backup',
#  'hour',
#  'us',
#  'idle',
#  'lie',
#  'amazon',
#  'lenove',
#  'battery',
#  'charger',
#  'hour',
#  'cash',
#  'phone',
#  'everthey',
#  'phone',
#  'problem',
#  'amazon',
#  'phone',
#  'amazon',
#  'camerawaste',
#  'money',
#  'phone',
#  'allot',
#  'reason',
#  'battery',
#  'level',
#  'problem',
#  'phone',
#  'hanging',
#  'problem',
#  'note',
#  'station',
#  'ahmedabad',
#  'year',
#  'phone',
#  'lenovo',
#  'lot',
#  'glitch',
#  'thing',
#  'option',
#  'wrost',
#  'phone',
#  'charger',
#  'damage',
#  'month',
#  'item',
#  'battery',
#  'life',
#  'battery',
#  'problem',
#  'motherboard',
#  'problem',
#  'month',
#  'mobile',
#  'life',
#  'phone',
#  'slim',
#  'battry',
#  'backup',
#  'screen',
#  'headset',
#  'time',
#  'product',
#  'prize',
#  'range',
#  'specification',
#  'comparison',
#  'mobile',
#  'range',
#  'phone',
#  'seal',
#  'credit',
#  'card',
#  'deal',
#  'amazon',
#  'battery',
#  'solution',
#  'battery',
#  'life',
#  'smartphone',
#  'galery',
#  'problem',
#  'speaker',
#  'phone',
#  'camera',
#  'battery',
#  'product',
#  'product',
#  'camera',
#  'o',
#  'battery',
#  'phone',
#  'product',
#  'option',
#  'cast',
#  'screen',
#  'wifi',
#  'call',
#  'option',
#  'mobile',
#  'hotspot',
#  'phone',
#  'usb',
#  'cable',
#  'phone',
#  'price',
#  'mobile',
#  'lenovo',
#  'display',
#  'specification',
#  'function',
#  'phone',
#  'fon',
#  'fon',
#  'speekars',
#  'phone',
#  'issue',
#  'color',
#  'screen',
#  'update',
#  'oreo',
#  'battery',
#  'heating',
#  'problem',
#  'update',
#  'phone',
#  'battery',
#  'update',
#  'oreo',
#  'one',
#  'sim',
#  'customer',
#  'service',
#  'performance',
#  'battery',
#  'camera',
#  'backup',
#  'pricefull',
#  'passa',
#  'wasole',
#  'phone',
#  'phone',
#  'performance',
#  'signal',
#  'restarts',
#  'phone',
#  'bcoms',
#  'plzz',
#  'dont',
#  'round',
#  'performance',
#  'span',
#  'day',
#  'trust',
#  'deal',
#  'amazon',
#  'disappointment',
#  'signal',
#  'problem',
#  'headache',
#  'problem',
#  'call',
#  'range',
#  'phone',
#  'rate',
#  'camera',
#  'quality',
#  'product',
#  'mobile',
#  'price',
#  'feature',
#  'mobile',
#  'price',
#  'quality',
#  'camera',
#  'min',
#  'quality',
#  'phone',
#  'issue',
#  'sell',
#  'phone',
#  'take',
#  'hr',
#  'charge',
#  'ekdam',
#  'network',
#  'problem',
#  'camera',
#  'quality',
#  'performance',
#  'phone',
#  'performance',
#  'rm',
#  'memory',
#  'superb',
#  'featurs',
#  'battery',
#  'value',
#  'money',
#  'lenovo',
#  'problem',
#  'speaker',
#  'breakup',
#  'problem',
#  'hour',
#  'phone',
#  'heating',
#  'problem',
#  'choice',
#  'battery',
#  'standby',
#  'problem',
#  'battery',
#  'camera',
#  'jet',
#  'speed',
#  'product',
#  'ok',
#  'screen',
#  'cast',
#  'tv',
#  'miracast',
#  'charging',
#  'hour',
#  'contact',
#  'file',
#  'google',
#  'card',
#  'total',
#  'device',
#  'usage',
#  'battery',
#  'day',
#  'con',
#  'phone',
#  'battery',
#  'mah',
#  'battery',
#  'camera',
#  'quality',
#  'depth',
#  'mode',
#  'focus',
#  'thing',
#  'device',
#  'display',
#  'india',
#  'ka',
#  'battery',
#  'offer',
#  'hour',
#  'network',
#  'signal',
#  'call',
#  'coverage',
#  'people',
#  'mobile',
#  'mobile',
#  'range',
#  'battery',
#  'backup',
#  'mark',
#  'weight',
#  'price',
#  'point',
#  'camera',
#  'mo',
#  'issue',
#  'system',
#  'system',
#  'update',
#  'superb',
#  'mobile',
#  'phone',
#  'product',
#  'delivery',
#  'gesture',
#  'feature',
#  'issue',
#  'brand',
#  'specification',
#  'focus',
#  'thanks',
#  'amazon',
#  'lenovo',
#  'buy',
#  'guy',
#  'verigood',
#  'product',
#  'time',
#  'naugat',
#  'product',
#  'cost',
#  'phone',
#  'feel',
#  'nerve',
#  'radiation',
#  'need',
#  'fix',
#  'matter',
#  'safety',
#  'security',
#  'issue',
#  'hardware',
#  'issue',
#  'service',
#  'center',
#  'location',
#  'availability',
#  'time',
#  'customer',
#  'product',
#  'feature',
#  'issue',
#  'recording',
#  'option',
#  'product',
#  'quality',
#  'snap',
#  'product',
#  'device',
#  'product',
#  'amazon',
#  'phone',
#  'hello',
#  'performance',
#  'device',
#  'picture',
#  'use',
#  'hour',
#  'data',
#  'battery',
#  'mode',
#  'performanc',
#  'turbo',
#  'charger',
#  'waste',
#  'charger',
#  'return',
#  'rest',
#  'etc',
#  'phone',
#  'problem',
#  'product',
#  'product',
#  'lot',
#  'malfunction',
#  'donot',
#  'product',
#  'look',
#  'sleekness',
#  'phone',
#  'feature',
#  'phone',
#  'phone',
#  'feature',
#  'sound',
#  'controler',
#  'option',
#  'shortcut',
#  'shutter',
#  'voice',
#  'call',
#  'recorder',
#  'camera',
#  'quality',
#  'performance',
#  'class',
#  'phone',
#  'time',
#  'lenovo',
#  'note',
#  'note',
#  'kind',
#  'thinking',
#  'load',
#  'battery',
#  'class',
#  'defuces',
#  'time',
#  'charge',
#  'time',
#  'othet',
#  'apps',
#  'stock',
#  'android',
#  'thing',
#  'ok',
#  'product',
#  'problem',
#  'lenovo',
#  'note',
#  'handset',
#  'time',
#  'charger',
#  'service',
#  'centre',
#  'month',
#  'fix',
#  'u',
#  'feature',
#  'gift',
#  'raping',
#  'poorwords',
#  'money',
#  'work',
#  'product',
#  'anyone',
#  'tv',
#  'cast',
#  'screen',
#  'option',
#  'option',
#  'device',
#  'chromecast',
#  'casting',
#  'model',
#  'phone',
#  'range',
#  'phone',
#  'u',
#  'feature',
#  'problem',
#  'arises',
#  'money',
#  'sim',
#  'slot',
#  'delivery',
#  'star',
#  'bcz',
#  'lenovo',
#  'fan',
#  'mobile',
#  'year',
#  'time',
#  'guess',
#  'phone',
#  'lot',
#  'feature',
#  'look',
#  'gaming',
#  'music',
#  'deca',
#  'core',
#  'processor',
#  'quad',
#  'core',
#  'phone',
#  'speaker',
#  'speaker',
#  'hole',
#  'buyer',
#  'camera',
#  'display',
#  'battery',
#  'keep',
#  'phone',
#  'use',
#  'battery',
#  'backup',
#  'problem',
#  'phone',
#  'product',
#  'cash',
#  'way',
#  'fool',
#  'cash',
#  'mobile',
#  'mobile',
#  'heating',
#  'problem',
#  'thing',
#  'popularity',
#  'segment',
#  'productcamera',
#  'greatsound',
#  'superb',
#  'mobile',
#  'process',
#  'drawback',
#  'turbo',
#  'charger',
#  'mobile',
#  'experience',
#  'lenovo',
#  'note',
#  'problem',
#  'battery',
#  'problem',
#  'camera',
#  'problem',
#  'plz',
#  'buy',
#  'phone',
#  'phone',
#  'mo',
#  'expectation',
#  'camera',
#  'mark',
#  'issue',
#  'need',
#  'lenovo',
#  'sale',
#  'dolby',
#  'feature',
#  'lenovo',
#  'switch',
#  'sofwares',
#  'phone',
#  'please',
#  'battery',
#  'camera',
#  'shadow',
#  'function',
#  'phone',
#  'performance',
#  'waste',
#  'money',
#  'phone',
#  'add',
#  'please',
#  'mi',
#  'brand',
#  'mobile',
#  'range',
#  'product',
#  'phone',
#  'lenovo',
#  'stock',
#  'android',
#  'story',
#  'battery',
#  'drain',
#  'time',
#  'camera',
#  'joke',
#  'update',
#  'lenovo',
#  'mobile',
#  'problem',
#  'quality',
#  'phn',
#  'battery',
#  'time',
#  'display',
#  'disadvantage',
#  'model',
#  'battery',
#  'feature',
#  'battery',
#  'backup',
#  'lenovo',
#  'note',
#  'model',
#  'type',
#  'day',
#  'product',
#  'problem',
#  'amazon',
#  'product',
#  'description',
#  'handset',
#  'slot',
#  'slot',
#  'support',
#  'whereas',
#  'support',
#  'effect',
#  'camera',
#  'support',
#  'sim',
#  'slot',
#  'disadvantage',
#  'feature',
#  'ram',
#  'delay',
#  'battery',
#  'delay',
#  'camera',
#  'operating',
#  'delay',
#  'contact',
#  'searching',
#  'contact',
#  'time',
#  'mobile',
#  'u',
#  'camera',
#  'camera',
#  'need',
#  'product',
#  'price',
#  'range',
#  'speaker',
#  'channel',
#  'speaker',
#  'camera',
#  'wakeup',
#  'earphone',
#  'quality',
#  'jbl',
#  'camera',
#  'product',
#  'product',
#  'phone',
#  'hang',
#  'hota',
#  'hai',
#  'phone',
#  'phone',
#  'connectivity',
#  'charging',
#  'talk',
#  'time',
#  'battery',
#  'twin',
#  'camera',
#  'hand',
#  'mine',
#  'update',
#  'connection',
#  'phone',
#  'information',
#  'gorilla',
#  'glass',
#  'screen',
#  'glass',
#  'phone',
#  'grasp',
#  'sofa',
#  'lenovo',
#  'screen',
#  'rating',
#  'star',
#  'delivery',
#  'delivery',
#  'district',
#  'phone',
#  'bit',
#  'notification',
#  'sound',
#  'bit',
#  'photo',
#  'lot',
#  'memory',
#  'clarity',
#  'memory',
#  'feature',
#  'return',
#  'note',
#  'mobile',
#  'performance',
#  'battery',
#  'battery',
#  'plz',
#  'batterybattery',
#  'drain',
#  'hrsit',
#  'mah',
#  'performance',
#  'configuration',
#  'auto',
#  'auto',
#  'touch',
#  'problem',
#  'jan',
#  'average',
#  'phone',
#  'price',
#  'camera',
#  'performance',
#  'day',
#  'ok',
#  'lenovo',
#  'name',
#  'expectation',
#  'phone',
#  'course',
#  'use',
#  'performance',
#  'product',
#  'specification',
#  'thanks',
#  'product',
#  'time',
#  'phone',
#  'term',
#  'specification',
#  'sound',
#  'battery',
#  'screen',
#  'camera',
#  'ram',
#  'rom',
#  'alongwith',
#  'gorilla',
#  'glass',
#  'thing',
#  'mobile',
#  'pocket',
#  'lack',
#  'pc',
#  'connection',
#  'etc',
#  'phone',
#  'update',
#  'phone',
#  'month',
#  'gb',
#  'memory',
#  'phone',
#  'camera',
#  'performance',
#  'mid',
#  'range',
#  'phone',
#  'ye',
#  'amazon',
#  'hai',
#  'phn',
#  'kharida',
#  'lenovo',
#  'note',
#  'game',
#  'ka',
#  'issue',
#  'hai',
#  'ly',
#  'bolte',
#  'hai',
#  'par',
#  'behanchod',
#  'hai',
#  'bhosdi',
#  'jane',
#  'ke',
#  'service',
#  'bhi',
#  'inka',
#  'bhosdi',
#  'game',
#  'khelke',
#  'kenya',
#  'hai',
#  'koi',
#  'problem',
#  'nai',
#  'hai',
#  'behanchod',
#  'phone',
#  'bhej',
#  'diya',
#  'mat',
#  'kaharidna',
#  'amazon',
#  'se',
#  'bhot',
#  'bhosdi',
#  'hai',
#  'volta',
#  'sm',
#  'phone',
#  'mode',
#  'thing',
#  'running',
#  'problem',
#  'till',
#  'phone',
#  'camera',
#  'phone',
#  'heating',
#  'problem',
#  'depth',
#  'effect',
#  'phone',
#  'depth',
#  'effect',
#  'mi',
#  'youif',
#  'holic',
#  'phone',
#  'selfie',
#  'compare',
#  'phone',
#  'price',
#  'range',
#  'phone',
#  'top',
#  'term',
#  'selfiein',
#  'term',
#  'processor',
#  'snapdragon',
#  'bcz',
#  'phone',
#  'battery',
#  'phone',
#  'processor',
#  'technology',
#  'snapdragon',
#  'nm',
#  'efficient',
#  'lenovo',
#  'day',
#  'battery',
#  'hr',
#  'phone',
#  'hr',
#  'usage',
#  'mind',
#  'con',
#  'phone',
#  'phone',
#  'problem',
#  'phone',
#  'quality',
#  'processor',
#  'turbo',
#  'feature',
#  'parfomce',
#  'product',
#  'mobile',
#  'day',
#  'record',
#  'instruction',
#  'note',
#  'product',
#  'hello',
#  'guy',
#  'kaji',
#  'phone',
#  'lenovo',
#  'note',
#  'feature',
#  'decide',
#  'bu',
#  'day',
#  'lenovo',
#  'game',
#  'temple',
#  'type',
#  'problem',
#  'opinion',
#  'guy',
#  'product',
#  'money',
#  'product',
#  'phone',
#  'battery',
#  'life',
#  'phone',
#  'issue',
#  'phone',
#  'call',
#  'recorder',
#  'backup',
#  'key',
#  'problem',
#  'mobile',
#  'performance',
#  'thanx',
#  'phone',
#  'wrost',
#  'mobile',
#  'charge',
#  'lot',
#  'tym',
#  'turbo',
#  'chrger',
#  'selfie',
#  'camera',
#  'mobile',
#  'handset',
#  'accessory',
#  'month',
#  'battery',
#  'something',
#  'issue',
#  'customer',
#  'super',
#  'description',
#  'software',
#  'update',
#  'product',
#  'ekdum',
#  'bakwas',
#  'performance',
#  'battery',
#  'camera',
#  'mistake',
#  'phone',
#  'battery',
#  'backup',
#  'phone',
#  'time',
#  'battery',
#  'side',
#  'button',
#  'problem',
#  'deapth',
#  'mode',
#  'finger',
#  'print',
#  'senser',
#  'camera',
#  'screen',
#  'gorilla',
#  'glass',
#  'phone',
#  'opinion',
#  'phone',
#  'work',
#  'battery',
#  'sim',
#  'data',
#  'camera',
#  'clarity',
#  'battery',
#  'backup',
#  'quality',
#  'product',
#  'age',
#  'group',
#  'thank',
#  'amazon',
#  'day',
#  'phone',
#  'price',
#  'battery',
#  'depth',
#  'camera',
#  'mode',
#  'thing',
#  'phone',
#  'day',
#  'use',
#  'phone',
#  'time',
#  'internet',
#  'lte',
#  'network',
#  'product',
#  'smartphone',
#  'bit',
#  'bug',
#  'cost',
#  'product',
#  'phone',
#  'issue',
#  'response',
#  'customer',
#  'care',
#  'service',
#  'center',
#  'crap',
#  'trap',
#  'phone',
#  'variant',
#  'phone',
#  'battery',
#  'performance',
#  'charging',
#  'time',
#  'phone',
#  'work',
#  'touchscreen',
#  'feature',
#  'r',
#  'performance',
#  'money',
#  'service',
#  'amazon',
#  'purchase',
#  'month',
#  'handy',
#  'touch',
#  'product',
#  'thanks',
#  'product',
#  'amazon',
#  'lenovo',
#  'issue',
#  'phone',
#  'phone',
#  'issue',
#  'technician',
#  'amazon',
#  'amount',
#  'piece',
#  'headphone',
#  'jack',
#  'hotspot',
#  'battery',
#  'lot',
#  'usage',
#  'moto',
#  ...]

# %% [markdown]
# #### Task 8: Create a topic model using LDA on the cleaned-up data with 12 topics.
#
# 1. Print out the top terms for each topic.
#
# 2. What is the coherence of the model with the c_v metric?

# %%
from gensim import corpora, models
import gensim

# %%
dictionary = corpora.Dictionary([lemmatized_wordlist])

# %%
print(dictionary)
# Out:
# Dictionary(6006 unique tokens: ['aa', 'aab', 'aachha', 'aaguthu', 'aaj']...)

# %%
print(dictionary.token2id)
# Out:
# {'aa': 0, 'aab': 1, 'aachha': 2, 'aaguthu': 3, 'aaj': 4, 'aajata': 5, 'aal': 6, 'aap': 7, 'aapki': 8, 'aapko': 9, 'aapne': 10, 'aaps': 11, 'aapse': 12, 'aashiyana': 13, 'aata': 14, 'aate': 15, 'aati': 16, 'aavashyakta': 17, 'aavdla': 18, 'aaya': 19, 'aayega': 20, 'aayi': 21, 'ab': 22, 'abhav': 23, 'abhi': 24, 'abhitak': 25, 'ability': 26, 'absence': 27, 'absent': 28, 'absolute': 29, 'acc': 30, 'acceptance': 31, 'acceserie': 32, 'accesorios': 33, 'access': 34, 'accesscustomer': 35, 'accessory': 36, 'accha': 37, 'acchaa': 38, 'accidental': 39, 'account': 40, 'accuracy': 41, 'acessories': 42, 'acha': 43, 'achaa': 44, 'achcha': 45, 'achchha': 46, 'ache': 47, 'achha': 48, 'acoumnt': 49, 'act': 50, 'action': 51, 'activity': 52, 'ad': 53, 'adagond': 54, 'adapter': 55, 'adaptor': 56, 'add': 57, 'addition': 58, 'address': 59, 'addressbest': 60, 'addverties': 61, 'adichaalum': 62, 'adjustment': 63, 'adobe': 64, 'adopter': 65, 'advance': 66, 'advantage': 67, 'advertisement': 68, 'advertising': 69, 'advice': 70, 'advise': 71, 'advocate': 72, 'advt': 73, 'adwans': 74, 'affect': 75, 'afrer': 76, 'afterall': 77, 'afternoon': 78, 'afterwards': 79, 'afterwords': 80, 'aftr': 81, 'agar': 82, 'age': 83, 'agency': 84, 'agent': 85, 'agr': 86, 'ahe': 87, 'ahmedabad': 88, 'air': 89, 'aircel': 90, 'airplane': 91, 'airte': 92, 'airtel': 93, 'aisa': 94, 'aka': 95, 'akash': 96, 'akdom': 97, 'al': 98, 'alarm': 99, 'alert': 100, 'algorithm': 101, 'aligarhthis': 102, 'allah': 103, 'alldrains': 104, 'allot': 105, 'allows': 106, 'allrounder': 107, 'allure': 108, 'almostlenovo': 109, 'aloneam': 110, 'alonepros': 111, 'alongwith': 112, 'alot': 113, 'alphabet': 114, 'alright': 115, 'alsovery': 116, 'alternate': 117, 'alternative': 118, 'aluminium': 119, 'aluminum': 120, 'alwas': 121, 'ama': 122, 'amaezon': 123, 'amateur': 124, 'amaxon': 125, 'amazing': 126, 'amazon': 127, 'amazoncamera': 128, 'amazone': 129, 'amazonnot': 130, 'amazonplease': 131, 'amazonpolicy': 132, 'amazonproduct': 133, 'amazonproducts': 134, 'amazonvery': 135, 'ambition': 136, 'amd': 137, 'amezon': 138, 'aminities': 139, 'amlets': 140, 'amoson': 141, 'amount': 142, 'amozon': 143, 'amp': 144, 'amplifier': 145, 'amz': 146, 'amzone': 147, 'an': 148, 'anad': 149, 'analog': 150, 'andaman': 151, 'andbattery': 152, 'ander': 153, 'andi': 154, 'andoid': 155, 'andreas': 156, 'andriod': 157, 'android': 158, 'androidfast': 159, 'androidmetal': 160, 'androidoleophobic': 161, 'androidvery': 162, 'ane': 163, 'angle': 164, 'animation': 165, 'annoying': 166, 'anroid': 167, 'answer': 168, 'antenna': 169, 'anti': 170, 'antivirus': 171, 'anybody': 172, 'anycast': 173, 'anyday': 174, 'anyone': 175, 'anyphone': 176, 'anything': 177, 'anythingfinger': 178, 'anythingwent': 179, 'anytime': 180, 'aone': 181, 'ap': 182, 'apearence': 183, 'apeksha': 184, 'aperture': 185, 'apk': 186, 'apko': 187, 'apn': 188, 'apne': 189, 'app': 190, 'appbattery': 191, 'appear': 192, 'appearance': 193, 'append': 194, 'apple': 195, 'appliance': 196, 'appliations': 197, 'application': 198, 'applock': 199, 'applocker': 200, 'appointing': 201, 'appreciation': 202, 'approach': 203, 'approx': 204, 'apps': 205, 'appthe': 206, 'april': 207, 'apse': 208, 'aqua': 209, 'aram': 210, 'arcade': 211, 'area': 212, 'arises': 213, 'arm': 214, 'armour': 215, 'arrange': 216, 'arrival': 217, 'arrive': 218, 'arrives': 219, 'art': 220, 'as': 221, 'asap': 222, 'asardar': 223, 'ase': 224, 'aside': 225, 'asin': 226, 'ask': 227, 'asks': 228, 'aso': 229, 'asom': 230, 'asome': 231, 'aspect': 232, 'aspection': 233, 'asphalt': 234, 'asseseris': 235, 'assist': 236, 'assistance': 237, 'assistant': 238, 'assistantgreat': 239, 'associate': 240, 'assories': 241, 'assure': 242, 'asus': 243, 'aswm': 244, 'aswome': 245, 'ata': 246, 'atall': 247, 'ate': 248, 'ati': 249, 'atiganum': 250, 'atleast': 251, 'atmis': 252, 'atmos': 253, 'atmosamazon': 254, 'atmosless': 255, 'atmosphere': 256, 'atmosstock': 257, 'atmosvr': 258, 'atom': 259, 'atomos': 260, 'att': 261, 'attach': 262, 'at ...

# %%
corpus = [dictionary.doc2bow(text) for text in [lemmatized_wordlist]]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=12, id2word=dictionary)

# %%
print(ldamodel)
# Out:
# LdaModel(num_terms=6006, num_topics=12, decay=0.5, chunksize=2000)

# %%
for idx, topic in ldamodel.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.080*"phone" + 0.034*"battery" + 0.030*"camera" + 0.021*"problem" + 0.020*"issue" + 0.020*"product" + 0.015*"mobile" + 0.013*"time" + 0.013*"quality" + 0.012*"lenovo"
#
#
# Topic: 1
# Words: 0.037*"phone" + 0.025*"camera" + 0.020*"battery" + 0.017*"product" + 0.014*"issue" + 0.012*"problem" + 0.012*"mobile" + 0.011*"day" + 0.010*"performance" + 0.009*"quality"
#
#
# Topic: 2
# Words: 0.067*"phone" + 0.030*"battery" + 0.028*"camera" + 0.022*"product" + 0.020*"problem" + 0.020*"mobile" + 0.013*"issue" + 0.012*"lenovo" + 0.010*"feature" + 0.010*"price"
#
#
# Topic: 3
# Words: 0.048*"phone" + 0.026*"battery" + 0.025*"product" + 0.023*"camera" + 0.019*"problem" + 0.016*"mobile" + 0.014*"quality" + 0.012*"day" + 0.012*"time" + 0.011*"issue"
#
#
# Topic: 4
# Words: 0.074*"phone" + 0.050*"camera" + 0.029*"battery" + 0.019*"problem" + 0.016*"mobile" + 0.014*"product" + 0.014*"quality" + 0.013*"note" + 0.012*"issue" + 0.012*"time"
#
#
# Topic: 5
# Words: 0.028*"phone" + 0.020*"camera" + 0.020*"battery" + 0.018*"product" + 0.012*"problem" + 0.012*"mobile" + 0.008*"issue" + 0.008*"performance" + 0.008*"quality" + 0.007*"price"
#
#
# Topic: 6
# Words: 0.059*"phone" + 0.038*"camera" + 0.032*"battery" + 0.021*"product" + 0.019*"problem" + 0.014*"issue" + 0.014*"mobile" + 0.012*"quality" + 0.011*"performance" + 0.011*"feature"
#
#
# Topic: 7
# Words: 0.052*"phone" + 0.037*"camera" + 0.026*"battery" + 0.024*"product" + 0.019*"issue" + 0.015*"quality" + 0.014*"problem" + 0.012*"mobile" + 0.012*"day" + 0.012*"time"
#
#
# Topic: 8
# Words: 0.074*"phone" + 0.039*"camera" + 0.032*"battery" + 0.027*"product" + 0.022*"quality" + 0.022*"mobile" + 0.016*"issue" + 0.016*"problem" + 0.013*"lenovo" + 0.012*"price"
#
#
# Topic: 9
# Words: 0.071*"phone" + 0.038*"battery" + 0.036*"camera" + 0.035*"product" + 0.018*"problem" + 0.017*"issue" + 0.017*"mobile" + 0.015*"quality" + 0.015*"time" + 0.013*"day"
#
#
# Topic: 10
# Words: 0.098*"phone" + 0.042*"battery" + 0.039*"camera" + 0.027*"product" + 0.019*"issue" + 0.018*"mobile" + 0.018*"problem" + 0.018*"quality" + 0.017*"note" + 0.013*"performance"
#
#
# Topic: 11
# Words: 0.038*"phone" + 0.027*"battery" + 0.024*"product" + 0.024*"camera" + 0.015*"problem" + 0.014*"mobile" + 0.012*"quality" + 0.010*"performance" + 0.010*"issue" + 0.009*"lenovo"

# %%
#coherence

from gensim.models.coherencemodel import CoherenceModel

# %%
cohmodel = CoherenceModel(model = ldamodel, texts=[lemmatized_wordlist], dictionary=dictionary, coherence='c_v')

# %%
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
coherence = cohmodel.get_coherence()

# %%
print(coherence)
